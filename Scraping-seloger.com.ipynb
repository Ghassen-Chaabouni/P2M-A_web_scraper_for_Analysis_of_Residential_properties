# %%
import pandas as pd
from bs4 import BeautifulSoup as soup
import requests
from selenium import webdriver
import time
from lxml import html
from random import random

# %%
category_data = []
localite_data = []
criterion_data = []
price_data = []
monthly_data = []
description_data = []
plus_data = []
energie_data = []

PROXY = "127.0.0.1:9150"
webdriver.DesiredCapabilities.FIREFOX['proxy']={
    "socksProxy":PROXY,
    "socksVersion":5,
    "proxyType":"MANUAL"
}

max = 20
min = 10

page_num1=29

page_num2=page_num1+1
for num in range(page_num1,page_num2):
    driver = webdriver.Firefox()
    driver.get("https://seloger.com//list.htm?projects=2%2C5&types=1%2C2%2C4%2C3%2C9%2C13%2C14%2C12%2C11%2C10&natures=1%2C2%2C4&places=%5B%7BidPays%3A250%7D%5D&enterprise=0&houseboat=1&qsVersion=1.0&LISTING-LISTpg="+str(num))
    time_random1 = random()
    time1 = min + (time_random1 * (max - min))
    time.sleep(time1)
    page = soup(driver.page_source, 'html.parser')
    house_containers = page.find_all("div", class_="block__ShadowedBlock-sc-10w6hsj-0 ListContent__SmartClassifiedExtended-sc-1viyr2k-2 iddbNe classified__ClassifiedContainer-sc-1wmlctl-0 cGCTai Card__CardContainer-sc-7insep-7 kjDrzL")
    print(len(house_containers))
    
    driver2 = webdriver.Firefox()
    for data in house_containers:
        find_link = data.find_all("a", class_="CoveringLink-a3s3kt-0 dXJclF")
        L=str(find_link[0]).split(" ")
        ad_link=L[3][14:-1]

        if('validate.perfdrive.com' in ad_link):
            driver2 = webdriver.Firefox()
            continue

        if ('seloger.com' not in ad_link):
            continue

        driver2.get("https://" + ad_link)
        time_random2 = random()
        time2 = min + (time_random2 * (max - min))
        time.sleep(time2)
        page2 = soup(driver2.page_source, 'html.parser')

        criterion = []
        plus = []
        energie =[]

        try:
            try:
                find_category = page2.find_all("h2", class_="c-h2")[0]
                category = str(find_category)[len('<h2 class="c-h2">'):-5]
            except IndexError:
                find_category = page2.find_all("div", class_="Summary__Text-sc-1wkzvu-6 gcWjRm")[0]
                category=(str(find_category)[len('<div class="Summary__Text-sc-1wkzvu-6 gcWjRm">'):-6])
        except:
            category = "NULL"

        try:
            try:
                find_localite = page2.find_all("p", class_="localite")[0]
                localite = str(find_localite)[len('<p class="localite">'):-4]
            except IndexError:
                find_localite = page2.find_all("div", class_="Summary__Text-sc-1wkzvu-6 gcWjRm")[1]
                localite=(str(find_localite)[len('<div class="Summary__Text-sc-1wkzvu-6 gcWjRm">'):-6])
        except:
            localite = "NULL"

        try:
            try:
                find_criterion = page2.find_all("ul", class_="criterion")[0]
                criterion2 = str(find_criterion).split('<li>')[1:]
                for i in range (len(criterion2)):
                    ch=""
                    for j in range (len(criterion2[i])):
                        if(str(criterion2[i])[j]=="<"):
                            break
                        ch=ch+str(criterion2[i])[j]
                    criterion.append(ch)

            except IndexError:
                find_criterion = page2.find_all("div", class_="Tags__TagContainer-sc-1gccxml-0 kQEoGa")[:3]
                find_criterion = list(map(str, find_criterion))
                for i in range (len(find_criterion)):
                    criterion.append(find_criterion[i][len('<div class="Tags__TagContainer-sc-1gccxml-0 kQEoGa">'):-6])

        except:
            criterion.append("NULL")

        try:
            try:
                find_price = page2.find_all("a", class_="js-smooth-scroll-link price")[0]
                price = str(find_price)[len('<a class="js-smooth-scroll-link price" data-smoothscroll-offset="160" href="#about_price_anchor">'):-4].replace(" ","").replace("\n","")
            except IndexError:
                find_price = page2.find_all("span", class_="global-styles__TextNoWrap-sc-1aeotog-7 iAJdaY")[0]
                price = str(find_price)[len('<span class="global-styles__TextNoWrap-sc-1aeotog-7 iAJdaY">'):-7]
        except:
            price = "NULL"

        try:
            try:
                find_monthly = page2.find_all("a", class_="monthly")[0]
                monthly = str(find_monthly)[len('<a class="monthly" href="https://e-immobilier.credit-agricole.fr/simulca/?ORI=selogercampagne&amp;xtor=AL-2-[partenariat]-[Seloger]-[pdd]-[lien_a_partir_sticky]" rel="nofollow" target="_blank">'):-len('<sup>1</sup></a>')]
            except IndexError:
                find_monthly = page2.find_all("span", class_="global-styles__TextNoWrap-sc-1aeotog-7 iAJdaY")[1]
                monthly = str(find_monthly)[len('<span class="global-styles__TextNoWrap-sc-1aeotog-7 iAJdaY">'):-7]
        except:
            monthly = "NULL"

        try:
            try:
                find_description = page2.find_all("p", class_="sh-text-light")[0]
                description = str(find_description)[len('<p class="sh-text-light" id="js-descriptifBien">'):-4]
            except IndexError:
                find_description = "NULL"
                description ="NULL"
        except:
            description = "NULL"

        try:
            try:
                find_plus = page2.find_all("div", class_="u-left")[0]
                find_plus = page2.find_all("div", class_="u-left")
                for i in range (len(find_plus)):
                    plus2 = str(find_plus[i]).replace('<div class="u-left">', "").replace("</div>", "")
                    plus.append(plus2)

            except IndexError:
                find_plus = page2.find_all("figcaption") + page2.find_all("li", class_="GeneralList__Item-sc-9gtpjm-1 dsevYN")
                for i in range (len(find_plus)):
                    ch=""
                    for j in range (len(str(find_plus[i]))):
                        if(str(find_plus[i])[j]=='>'):
                            k=j
                            while(str(find_plus[i])[k]!="<"):
                                ch=ch + str(find_plus[i])[k]
                                k=k+1
                            break
                    plus.append(ch[1:])
        except:
            plus.append("NULL")

        try:
            try:
                find_energie = page2.find_all("div", class_="info-detail")[0]
                find_energie = page2.find_all("div", class_="info-detail")

                energie.append(str(find_energie[0])[len('<div class="info-detail">'):-6])
                energie.append(str(find_energie[1])[len('<div class="info-detail">'):-6])

            except IndexError:
                find_energie = page2.find_all("span", class_="Preview__PreviewTooltipValue-sc-1pa12ii-4 eGDcBO")
                energie.append(str(find_energie[0])[len('<span class="Preview__PreviewTooltipValue-sc-1pa12ii-4 eGDcBO">'):-7])
                energie.append(str(find_energie[1])[len('<span class="Preview__PreviewTooltipValue-sc-1pa12ii-4 eGDcBO">'):-7])
        except:
            energie.append("NULL")
            energie.append("NULL")


        print(category)
        print(localite)
        print(criterion)
        print(price)
        print(monthly)
        print(description)
        print(plus)
        print(energie)
        print("-----------------------------------------------------")

        category_data.append(str(category))
        localite_data.append(str(localite))
        criterion_data.append(criterion)
        price_data.append(str(price))
        monthly_data.append(str(monthly))
        description_data.append(str(description))
        plus_data.append(plus)
        energie_data.append(energie)

        # driver2.quit()
        
    for i in range (len(criterion_data)):
        if (len(criterion_data[i])==1):
            if("pièce" in criterion_data[i][0]):
                criterion_data[i].insert(1, "NULL")
                criterion_data[i].insert(2, "NULL")
            if("chambre" in criterion_data[i][0]):
                criterion_data[i].insert(0, "NULL")
                criterion_data[i].insert(2, "NULL")
            if("m²" in criterion_data[i][0]):
                criterion_data[i].insert(0, "NULL")
                criterion_data[i].insert(1, "NULL")
        if (len(criterion_data[i])==2):
            if(("pièce" in criterion_data[i][0]) and ("chambre" in criterion_data[i][1])):
                criterion_data[i].insert(2, "NULL")
            if(("pièce" in criterion_data[i][0]) and ("m²" in criterion_data[i][1])):
                criterion_data[i].insert(1, "NULL")
            if(("chambre" in criterion_data[i][0]) and ("m²" in criterion_data[i][1])):
                criterion_data[i].insert(0, "NULL")
        if(len(criterion_data[i])==0):
            criterion_data[i].append("NULL")
            criterion_data[i].append("NULL")
            criterion_data[i].append("NULL")
        
    df = pd.DataFrame()
    df["category"] = category_data
    df["localite"] = localite_data
    df["piece"] = [i[0] for i in criterion_data]
    df["chambres"] = [i[1] for i in criterion_data]
    df["area"] = [i[2] for i in criterion_data]
    df["price"] = price_data
    df["monthly"] = monthly_data
    df["description"] = description_data
    df["Diagnostic de performance énergétique(kWhEP/m².an)"] = [i[0] for i in energie_data]
    df["Indice d'émission de gaz à effet de serre(kgeqCO2/m².an)"] = [i[1] for i in energie_data]
    df["plus"] = plus_data
    df["type"] = "Acheter"
    
    df.to_csv(r"C:\Users\admin\Desktop\9raya\page.csv", index=False)
    csv1 = pd.read_csv(r"C:\Users\admin\Desktop\9raya\page.csv")
    csv2 = pd.read_csv(r"C:\Users\admin\Desktop\9raya\full_data.csv")
    full_data = pd.concat([csv1, csv2])
    full_data.to_csv(r"C:\Users\admin\Desktop\9raya\full_data.csv", index=False)
# Out:
# 25
# Maison / Villa
# St Orens de Gameville
# ['5 pièces', '4 chambres', '102 m²']
# 354 500€
# À partir de 1 470 € / mois
# Exclusivité CABINET BEDIN - Saint ORENS DE GAMEVILLE. Une maison de plain pied de 101 m², implantée sur un terrain de 600 m² arboré. Situé au coeur de la commune de Saint-Orens de Gameville, elle bénéficie d'un cadre de vie privilégié. Très fonctionnelle, elle offre de belles pièces à vivre: une cuisine, un séjour, 4 grandes chambres donnant sur un beau jardin, une salle d'eau avec douche et WC séparés. Un sous-sol entier aménageable avec un garage qui peut recevoir jusqu'à 4 voitures. Écoles, commerces, lycée accessible à pieds., Surface Carrez 101m².
# ['Surface de 102 m²', '5 Pièces', '4 Chambres', "1 Salle d'eau", '1 Toilette', 'Chauffage fuel', 'Séjour', 'Séjour de 23 m²', 'Terrain de 609 m²']
# ['373', '90']
# -----------------------------------------------------
# Maison / Villa
# Triel sur Seine
# ['7 pièces', '5 chambres', '165 m²']
# 469 000€
# À partir de 1 942 € / mois
# UNE EXCLUSIVITÉ AGENCE PRINCIPALE: Une maison individuelle rare sur le secteur !! Cette maison idéalement située à 5 min à pied des écoles (Collège, Primaire, Maternelle), commerces et transports (Gare et bus). Comprend une entrée donnant sur un Séjour/Salle à manger très lumineux (Exposition SUD-OUEST) avec cheminée et donnant accès direct sur une terrasse. Une belle cuisine équipée avec de beaux volumes. Une chambre et une suite parentale avec sa salle d'eau complètent le rez-de-chaussée. A l'étage vous disposerez d'une grande pièce palière, 3 chambres et une salle d'eau supplémentaire. La maison est édifiée sur un SOUS-SOL TOTAL avec possibilité de garer plusieurs véhicules. A VISITER AU PLUS VITE AVEC L'AGENCE PRINCIPALE (Collaborateur salarié).
# ['Cheminée', '1 Terrasse', 'Surface de 165 m²', 'Année de construction 1978', 'Bâtiment de 3 étages', '7 Pièces', '5 Chambres', '1 Salle de bain', "1 Salle d'eau", '3 Toilettes', 'Chauffage individuel gaz', 'Cuisine équipée', 'Entrée', 'Salle À Manger', 'Séjour', '1 Box', 'Terrain de 581 m²']
# ['156', '36']
# -----------------------------------------------------
# Appartement
# Echirolles
# ['4 pièces', '3 chambres', '83 m²']
# 235 000€
# À partir de 969 € / mois
# Secteur Frange verte, venez découvrir ce beau T4 de 83 m² situé en rez-de-chaussée surélevé, bénéficiant d'une grande terrasse exposée SUD/OUEST de 150 m², dont 44 m² de jardin, avec pergola et abri de jardin. Un bon compromis entre maison et appartement !
#  Il se compose d'une pièce de vie de 32 m², ouverte sur une cuisine équipée, avec accès sur la terrasse en partie couverte.
#  Un coin nuit avec 3 chambres donnant également sur la terrasse, dont 2 avec placards, un cellier, une salle de bains avec baignoire et un WC séparé.
#  Une cave accompagne ce bien.
#  Possibilité d'acquérir un garage en sus.
#  Visite virtuelle sur demande.
#  A visiter sans tarder avec DE FARIA Jennifer / - Annonce rédigée et publiée par un Agent Mandataire -.
# ['Ascenseur', 'Cave', 'Cave de 4 m²', '1 Terrasse', 'Orientation Est, Ouest, Sud', 'Surface de 83 m²', 'Année de construction 2001', 'Bâtiment de 4 étages', 'Au rez-de-chaussée', '4 Pièces', '3 Chambres', '1 Salle de bain', '1 Toilette', 'Rangements', 'Chauffage gaz radiateur', 'Cuisine américaine équipée', 'Séjour de 33 m²', 'Interphone']
# ['155', '36']
# -----------------------------------------------------
# Maison / Villa
# Chartres
# ['5 pièces', '3 chambres', '100 m²']
# <spanclass="bouquet">Bouquet</span>32 100€
# À partir de 141 € / mois
# Descriptif du bien: CHARTRES (gare SNCF, Autoroute)
# A 10 minutes à pied du Centre de CHARTRES,
# 1 Heure de Paris,
# Charmante maison idéalement située comprenant au rez-de-chaussée: véranda carrelée et double vitrage aluminium, cuisine aménagée équipée, WC et rangement.
# A l'étage: 3 chambres, salle de bains - douches, WC.
# En dépendance: un garage et une buanderie.
# Le tout sur un joli terrain clos et arboré de 222 m².
# Elle est située près de toutes commodités, centre commercial à pied, maternelle, primaire et collège et lycées autour de la maison.
# Investissement locatif dans un secteur prisé, ou future r
# ésidence, vous réaliserez avant tout un placement sécurisé et à très forte rentabilité.
# Analyse financière: VIAGER OCCUPÉ.
# Vous achetez ce bien en versant un apport de 32 100 EUR FAI (frais d'agence inclus) à la signature de l'acte authentique chez le notaire, et une mensualité de 275 EUR sur la durée.
# Surnommée capitale de la lumière et du parfum,
# CHARTRES charmante ville à moins d'une heure de Paris-Montparnasse, la ville compte 35 dessertes TER quotidiennes, un plus. Selon l'agglomération, pas moins de 8 000 salariés prennent quotidiennement le train pour rejoindre leur travail en région parisienne. Sa desserte ferroviaire, mais aussi routière et autoroutière (A 11, N10, A 154..), lui a également valu les faveurs de nombreuses entreprises. Sa " Cosmetic Valley ", qui concentre quelque 400 entreprises liées à l'industrie du soin corporel et du parfum parmi les plus prestigieuses (Paco Rabanne, Lancaster Group..), l'a hissée au premier rang mondial de ce secteur très convoité.
# Chartres possède également des atouts touristiques comme sa cathédrale. L'Odyssée, le fameux centre aquatique qui fait partie des plus grands d'Europe attirent également de nombreux visiteurs.
# C'est aussi le développement des transports ferroviaires pour se rendre a Paris ainsi qu'à TOURS et ORLÉANS.
# Avec le Grand Paris qui se profile, il y a fort à parier que CHARTRES va encore se développer et séduire tous nos investisseurs.
# ['Surface de 100 m²', '5 Pièces', '3 Chambres', '1 Salle de bain', '1 Toilette', 'Toilettes Séparées', 'Rangements', 'Chauffage gaz collectif', 'Cuisine séparée équipée', 'Terrain de 222 m²']
# ['204', '47']
# -----------------------------------------------------
# Maison / Villa
# St Quentin
# ['6 pièces', '4 chambres', '147 m²']
# <spanclass="bouquet">Bouquet</span>71 042€
# À partir de 302 € / mois
# Descriptif du bien: Villers Guislain - 25 mn de Cambrai - 30 mn de Saint Quentin.
# Maison lumineuse, dans un secteur calme, Vous tomberez sous le charme de cette demeure.
# Cette splendide villa sans vis à vis d'environ 147 m², agencée par de vastes espaces, beaux volumes sous plafond avec des matériaux de qualités comprend:
# - Au rez-de-chaussée: d'une entrée, salon-séjour très lumineux, un 2nd salon, une cuisine aménagée, WC
# - à l'étage 3 chambres, une salle de bain, combles et débarras.
# - Un parking, dépendances, Atelier, cave et un jardin arboré
# Une réelle opportunité à saisir.
# Analyse financière: Villers Guislain - 25 mn de Cambrai - 30 mn de Saint Quentin.
# Vous investissez dans cette maison de 147 m² offrant une situation idéale dans un secteur recherché.
# Economisez 57 658 EUR en achetant cet maison.
# Partant d'une valeur de 128 700 EUR, vous achetez ce bien sur la base d'une valeur occupée de 71 042 EUR seulement soit 483 EUR du m².
# Vous verserez à l'acquisition 71 042 EUR (honoraires inclus), aucune rente de prévue.
# Investissez à prix réduit dans un secteur attractif, et préparez votre future retraite tout en permettant à des seniors de mieux vivre la leur.
# ['Cave', 'Surface de 147 m²', 'Année de construction 1930', '6 Pièces', '4 Chambres', '1 Salle de bain', '1 Toilette', 'Toilettes Séparées', 'Chauffage gaz collectif', 'Cuisine séparée', 'Entrée', 'Séjour', '1 Parking', 'Terrain de 395 m²', 'Calme']
# ['223', '30']
# -----------------------------------------------------
# Maison / Villa
# Teurtheville Bocage
# ['10 pièces', '4 chambres', '270 m²']
# 436 800€
# À partir de 1 809 € / mois
# A 10 minutes de Saint Vaast la Hougue, depuis sa belle avenue, accedez au superbe corps de ferme. Maison de 270 m² et dépendances sur environ 7000 m².
#  Anciene boulangerie avec étang. A l'arrière piscine chauffée et grande terrasse exposition sud ouest.
#  Côté habitation,
#  rez-de-chaussée: entrée, cuisine aménagée équipée avec cheminée, arrière cuisine, bureau, cellier donnant accès au grenier exploitable. Séjour, salon avec cheminée insert, pièce dressing.
#  Etage: 4 chambres, dont 3 avec salles d'eau privatives.
#  Plusieurs dépendances de grandes surfaces à exploiter, garages, étables, celliers, anciennes laiterie rénovée.
#  Fort potenciel pour activités professionelles, gîtes, ou chambres d'hôtes.
# Cette annonce vous est proposée par Nicolas Guillotin, NoRSAC: 2019AC00187, Enregistré à Greffe du tribunal de commerce de La Roche Sur Yon Côté France Immobilier - Réseau Immobilier Franco Belge - Des conseillers du Nord au Sud de la France et 4 agences à votre service - Annonce rédigée et publiée par un Agent Mandataire -.
# ['Cheminée', 'Orientation Est, Ouest, Sud', 'Piscine', 'Surface de 270 m²', 'Bâtiment de 2 étages', '10 Pièces', '4 Chambres', "3 Salles d'eau", '3 Toilettes', 'Cuisine séparée équipée', 'Entrée', 'Séjour', 'Séjour de 30 m²', 'Terrain de 6976 m²']
# ['NULL', 'NULL']
# -----------------------------------------------------
# Appartement
# Neuilly sur Seine
# ['4 pièces', '3 chambres', '95 m²']
# 1 500 000€
# À partir de 6 190 € / mois
# Place Winston Churchill. Appartement 4 pièces de 95 m² (94,02 m² carrez) au dernier étage avec ascenseur d'un immeuble haussmannien de très bon standing. Entrée, double séjour avec balcon, cuisine indépendante, 2 ou 3 chambres, salle de bains avec WC, WC séparés, cave et une chambre de service. Calme et lumineux. Idéalement situé aux pieds des commerces et des transports. Situation recherchée. A restaurer. Secteur carte scolaire: Collège Maurois et lycée Pasteur. Charges annuelles: 3.504 €. Soumis au statut de la copropriété. Nombre de lots: 3. Prix de vente: 1.500.000 Euros FAI comprenant 3,33% d'honoraires d'agence à la charge de l'acquéreur. Groupe Building Partners, fort d'une expertise de plus de 25 ans, est spécialisé dans la transaction de biens "Familiaux de Standing" et bénéficie d'implantations de choix dans l'ouest parisien. C'est avec plus de 450 appartements, maisons et hôtels particuliers que Building Partners offre le plus large choix de biens à la vente. N'hésitez pas à nous solliciter, votre futur bien est chez nous au 7 bis rue Ernest Deloison à Neuilly-Sur-Seine ou par téléphone.
# ['Ascenseur', 'Cave', '1 Balcon', 'Gardien', 'Balcon de 3 m²', 'Orientation Ouest', 'Vue', 'Surface de 95 m²', 'Année de construction 1897', 'Bâtiment de 5 étages', 'Au 5ème étage', '4 Pièces', '3 Chambres', '1 Salle de bain', '2 Toilettes', 'Toilettes Séparées', 'Parquet', 'Rangements', 'Télévision Par Câble', 'Chauffage individuel gaz', 'Cuisine séparée', 'Entrée', 'Séjour', 'Séjour de 35 m²', 'Situation ville', 'Alarme', 'Interphone', 'Digicode', 'Calme']
# ['338', '79']
# -----------------------------------------------------
# Maison / Villa
# Mantes la Ville
# ['5 pièces', '3 chambres', '86 m²']
# 234 042€
# À partir de 973 € / mois
# Une superbe EXCLUSIVITÉ, un gage de qualité. A 5mn à pied de la gare, proche toutes commodités, maison individuelle élevée sur sous-sol total avec pièce à vivre, salle d'eau/WC, atelier, garage, chaufferie, cave. Elle est composée d'une entrée, cuisine aménagée, séjour de 40 m² (chambre possible) donnant accès à 2 terrasses, 2 chambres, salle de bains, WC, rangements. Grenier aménageable. Installation immédiate !!. A vous de faire vivre son intérieur !
# ['Cave', '2 Terrasses', 'Orientation Sud', 'Surface de 86 m²', 'Année de construction 1970', 'Bâtiment de 1 étage', '5 Pièces', '3 Chambres', '1 Salle de bain', "1 Salle d'eau", '2 Toilettes', 'Rangements', 'Chauffage individuel fuel radiateur', 'Entrée', 'Séjour', 'Terrain de 432 m²']
# ['294', '88']
# -----------------------------------------------------
# Appartement
# Boulogne Billancourt
# ['3 pièces', '2 chambres', '66 m²']
# 640 000€
# À partir de 2 646 € / mois
# L'Agence du Quartier vous propose de visiter cet appartement en VRAIE VISITE 3D vous permettant de vous déplacer dans l'appartement à votre guise: bouton VISITE 3D en bas à gauche des photos ! RIVES DE SEINE - Allée Georges Askinazi/ Quai Georges Gorse, à proximité de l'Île Séguin et de la Seine Musicale, magnifique appartement de 66 m² au 4ème étage d'un immeuble achevé en 2009 comprenant entrée avec placard, séjour avec cuisine ouverte entièrement équipée, le tout ouvert sur un premier balcon de 8 m² bénificiant d'une vue sur la Seine, deux chambres avec rangements dont une bénéficiant d'un grand dressing, donnant accès à un deuxième balcon, une salle de bains, un placard ainsi qu'un WC séparé. Emplacement de parking en sus du prix à 25.000 €. Nombreux rangements. Calme. Parfait état. Très lumineux. Métro 9 à proximité. Charges annuelles: 3252 €. Taxe foncière: 967 € Lots: 128 L'Agence du Quartier, 8 Rue Liot 92100 Boulogne-Billancourt.
# ['Ascenseur', '2 Balcons', 'Gardien', 'Surface de 66 m²', 'Année de construction 2010', 'Au 4ème étage', 'Adapté Pmr', '3 Pièces', '2 Chambres', '1 Salle de bain', '1 Toilette', 'Rangements', 'Chauffage central', 'Cuisine américaine', 'Entrée', 'Séjour', 'Séjour de 20 m²', '1 Parking', 'Interphone', 'Digicode', 'Calme']
# ['NULL', 'NULL']
# -----------------------------------------------------
# Appartement
# Rueil Malmaison
# ['3 pièces', '2 chambres', '49 m²']
# 299 000€
# À partir de 1 241 € / mois
# Stéphane Plaza Immobilier a le plaisir de vous présenter un appartement de 3 pièces en rez-de-jardin, au calme et sans vis-à-vis. Il bénéficie d'une terrasse de 11m², au sein d'une petite co-propriété de 6 lots dans le secteur des martinets, entre le centre ville et la gare. Il se compose d'un séjour avec une cuisine US aménagée, deux chambres, une salle de bains avec WC et une salle d'eau avec WC. Une cave complète ce bien. Copropriété de 6 lots (Pas de procédure en cours). Charges annuelles: 600.00 euros.
# ['Cave', '1 Terrasse', 'Surface de 49 m²', 'Année de construction 1967', 'Bâtiment de 1 étage', 'Au rez-de-chaussée', '3 Pièces', '2 Chambres', '1 Salle de bain', "1 Salle d'eau", '2 Toilettes', 'Chauffage individuel gaz radiateur', 'Cuisine américaine équipée', 'Séjour', 'Calme']
# ['267', '62']
# -----------------------------------------------------
# Appartement
# Rueil Malmaison
# ['3 pièces', '2 chambres', '63 m²']
# 430 000€
# À partir de 1 781 € / mois
# Stéphane Plaza Immobilier a le plaisir de vous présenter ce charmant 3 pièces refait à neuf dans un immeuble récent, dans le secteur des bords de Seine, à 3 minutes à pied de la gare. Il se compose d'un grand séjour de 30 m², une cuisine US intégralement équipée, deux chambres, une salle de bains et un WC séparé. Un parking en sous-sol sécurisé complète ce bien. Bien rare sur le marché. On vous attend pour les visites !
# ['Ascenseur', 'Surface de 63 m²', 'Année de construction 1998', 'Bâtiment de 7 étages', 'Au 1er étage', '3 Pièces', '2 Chambres', '1 Salle de bain', '1 Toilette', 'Chauffage individuel gaz radiateur', 'Cuisine équipée', 'Séjour']
# ['95', '90']
# -----------------------------------------------------
# Appartement
# Paris 19ème
# ['3 pièces', '1 chambre', '60 m²']
# 509 000€
# À partir de 2 106 € / mois
# Dans un Immeuble 1860 au 5ème étage sans ascenseur, un appartement de 2/3 pièces d'une surface au sol de 60m² dont 59,08 Carrez, exposition SUD, ensoleillé sur cour très calme. L'appartement est composé d'un beau double séjour avec parquet ancien et cheminée, une grande chambre avec 2 fenêtres, possibilité de créer une seconde chambre en enfilade, une cuisine aménagée dînatoire, une salle d'eau avec fenêtre, WC séparé, fenêtres double-vitrage. 2 caves réunies en 1 complètent ce bien. Métro Stalingrad, rue d'Aubervilliers, commerces à proximité, proche du Canal Saint-Martin et du Bassin de la Villette. Copropriété: 53 lots dont 35 lots principaux. Quote-part budget prévisionnel annuel: 2.247€. Classe d'énergie E. Prix affiché honoraires inclus à 3,88% TTC.
# ['Cheminée', 'Cave', 'Orientation Sud', 'Surface de 60 m²', 'Année de construction 1860', 'Bâtiment de 6 étages', 'Au 5ème étage', '3 Pièces', '1 Chambre', "1 Salle d'eau", '1 Toilette', 'Parquet', 'Chauffage individuel électrique', 'Séjour', 'Digicode', 'Calme']
# ['238', '15']
# -----------------------------------------------------
# Appartement
# Bagneux
# ['3 pièces', '2 chambres', '53 m²']
# 336 000€
# À partir de 1 394 € / mois
# Hosman vous propose à la vente ce 3 pièces d'une surface de 53.97 m² Carrez, situé Rue du Moulin Blanchard à Bagneux. L'appartement est situé au 1er étage sur 3 d'un immeuble de 2011.Un ascenseur est présent dans l'immeuble.Le bien se compose: D'une entrée de 2.64 m². D'un débarras et de nombreux placards (4.46 m²) D'un séjour spacieux de 19.60 m², exposé Nord Est qui donne sur les jardins verdoyants des voisins, très calme.Un balcon de 6.52 m² est rattaché au séjour et est exposé nord est sur les jardins. D'une chambre d'une surface de 9.47m2D'une cuisine aménagée de 6.19 m² bien agencé, et en bon état. D'une salle de bain de 3.25 m², équipée d'une simple vasque, d'une baignoire, de sèche serviette.Ce bien comporte également des toilettes séparées.Une place de parking intérieure boxée est vendue avec ce bien.Un local à vélo / un local à poussette est également présent dans l'immeuble.Le bien est situé dans le quartier de la crèche des Petits Moulins, au pied de la coulée verte, à Bagneux. Sa situation est calme.Le bien est à proximité des commerces, du marché, des écoles, et des transports: - en bus, à 15 minutes de la porte d'Orléans. - future station de métro du grand Paris à proximité.Le système de chauffage est individuel - électriqueLes charges de copropriété s'élèvent à 250 euros par trimestre, ce qui comprend l'entretien des parties communes, gestion des poubelles.La taxe foncière est de 1041 euros.Le bien est soumis au statut de copropriété.Chez Hosman, nous souhaitons réinventer l'agence immobilière en offrant un service innovant et transparent aux acheteurs et aux vendeurs.Nos frais de commercialisation sont de 4 900 euros fixes à la charge du vendeur. L'équipe Hosman se tient à votre disposition pour répondre à vos questions, organiser une visite ou une estimation de votre bien actuel si cet achat dépend de la vente de votre domicile.
# ['Ascenseur', '1 Balcon', 'Balcon de 7 m²', 'Orientation Nord', 'Surface de 53 m²', 'Bâtiment de 3 étages', 'Au 1er étage', '3 Pièces', '2 Chambres', '1 Salle de bain', '1 Toilette', 'Toilettes Séparées', 'Rangements', 'Chauffage individuel', 'Cuisine séparée', 'Entrée', 'Séjour', 'Calme']
# ['209', '10']
# -----------------------------------------------------
# Maison / Villa
# Louviers
# ['6 pièces', '4 chambres', '140 m²']
# 342 000€
# À partir de 1 418 € / mois
# Située sur les hauteurs de Louviers, au coeur d'un hameau très calme et résidentiel, belle maison d'environ 140 m² habitable pour un total utile d'environ 170 m², édifiée sur un beau jardin clos et arboré de 2187 m² avec au fond une mare naturelle. Maison composée au rez-de-chaussée: Entrée, salon-salle à manger, cuisine aménagée – équipée, cellier, WC, accès garage. 1er étage: 4 chambres dont une avec balcon, salle d'eau, WC. Garage deux voitures et buanderie d'environ 30 m², Chalet Canadien équipé d'un jacuzzi et d'une douche. Gaz de ville, double vitrage, alarme, isolation de l'étage refaite en 2011 par floconnage. Belle maison familiale en parfait état, accès autoroute A13 à 5 minutes. Honoraires charge vendeur Agent Commercial Sextant France - David Ledin agent basé à VERNON - Plus d'informations réf. 12701.
# ['Surface de 140 m²', 'Bâtiment de 1 étage', '6 Pièces', '4 Chambres', "1 Salle d'eau", '2 Toilettes', 'Chauffage gaz', 'Cuisine séparée équipée', 'Entrée', 'Salle À Manger', 'Séjour de 35 m²', '2 Boxes', 'Terrain de 2187 m²', 'Situation campagne', 'Calme']
# ['191', '44']
# -----------------------------------------------------
# Maison / Villa
# Conches en Ouche
# ['8 pièces', '6 chambres', '178 m²']
# 353 000€
# À partir de 1 464 € / mois
# Pour les amoureux de nature et de calme, authentique manoir Normand d'environ 180 m², édifié sur un parc arboré de 4065 m² sans aucune mitoyenneté ni vis-à-vis. Composé au rez-de-chaussée: Entrée, dressing, salon, salle à manger, cuisine aménagée, WC. 1er étage: 5 chambres dont une avec salle d'eau, salle de bains, WC, petit grenier. 2ème étage: 1 chambre. 3ème étage (tourelle): Une petite pièce. Bien extrêmement rare par son emplacement, idéal pour les personnes souhaitant être loin de tout voisinage, à voir absolument. Honoraires charge vendeur Agent Commercial Sextant France - David Ledin agent basé à VERNON - Plus d'informations réf. 11922.
# ['1 Balcon', 'Surface de 178 m²', 'Bâtiment de 3 étages', '8 Pièces', '6 Chambres', '1 Salle de bain', "1 Salle d'eau", '2 Toilettes', 'Chauffage gaz', 'Cuisine séparée équipée', 'Entrée', 'Salle À Manger', 'Séjour de 39 m²', 'Terrain de 4065 m²', 'Situation campagne', 'Calme']
# ['255', '70']
# -----------------------------------------------------
# Maison / Villa
# Heudreville sur Eure
# ['6 pièces', '4 chambres', '232 m²']
# 534 000€
# À partir de 2 209 € / mois
# Située sur les hauteurs de la vallée d'Eure, au coeur d'un secteur très calme, édifiée sur un jardin de 2000 m² entièrement clos. Villa d'architecte de 2017, d'environ 232 m² habitable, très spacieuse, offrant de grands volumes très lumineux. Composée au rez-de-jardin: Entrée, salon-salle à manger avec cuisine ouverte aménagée-équipée l'ensemble pour une surface d'environ 90 m², arrière-cuisine, chambre avec un grand dressing et salle d'eau privative, WC. 1er étage: Palier, 3 grandes chambres avec salle d'eau privative et WC dont une avec dressing. Domotique, chauffage au sol - pompe à chaleur, maison économe en énergie Garage 2 voitures. Idéal pour les amoureux du contemporain, à voir ! Honoraires charge vendeur Agent Commercial Sextant France - David Ledin agent basé à VERNON - Plus d'informations réf. 11446.
# ['Surface de 232 m²', 'Année de construction 2017', 'Bâtiment de 1 étage', '6 Pièces', '4 Chambres', "4 Salles d'eau", '4 Toilettes', 'Cuisine américaine équipée', 'Entrée', 'Salle À Manger', 'Séjour de 65 m²', '2 Boxes', 'Terrain de 2000 m²', 'Situation campagne', 'Calme']
# ['43', '2']
# -----------------------------------------------------
# Maison / Villa
# Clamart
# ['5 pièces', '3 chambres', '145 m²']
# 740 000€
# À partir de 3 058 € / mois
# Au Petit Clamart, magnifique maison de 145 m² habitable édifiée sur une parcelle de 316 m², composée de la manière suivante: Au Rez-de chaussée; une belle entrée, un grand salon-salle à manger avec cuisine ouverte, le tout de plain-pied donnant sur une grande terrasse d'environ 25 m². A l'étage; vous trouverez un bureau ainsi que deux grandes chambres de plus 12 m² dont une suite parentale avec loggia, une salle de douche et un grand dressing. Au sous-sol; une belle surface utile avec un garage, une cave et une buanderie. En fond de parcelle se trouve une charmante dépendance de 22 m² entièrement rénovée. En complément, profitez d'un beau jardin d'environ 120 m². Possibilité de stationner deux véhicules dans la cour. Vous serez séduit par le charme de cette maison, ses beaux volumes et la qualité des matériaux.
# ['Cheminée', '1 Balcon', '1 Terrasse', 'Surface de 145 m²', 'Année de construction 2000', 'Bâtiment de 1 étage', '5 Pièces', '3 Chambres', '1 Salle de bain', "1 Salle d'eau", 'Chauffage gaz radiateur', 'Cuisine équipée', 'Entrée', 'Salle À Manger', '1 Box', 'Terrain de 316 m²']
# ['NULL', 'NULL']
# -----------------------------------------------------
# Appartement
# Montpellier
# ['3 pièces', '2 chambres', '60 m²']
# 160 400€
# À partir de 670 € / mois
# LES AIGUERELLES, Idéalement situé, proche du centre ville et de la nouvelle mairie.
#  Accès rapide à l'autoroute et la route des plages.
#  Proches des transports, et de toutes les commodités
#  j'ai le plaisir de vous présenter ce bel appartement de 60 m², rénové, situé au 3ème étage d'une résidence de 4 étage sans ascenseur.
#  Il se compose d'un séjour de plus de 16 m², d'une cuisine équipée, é chambre, d'une buanderie, et d'une salle de bains et de WC.
#  Vous n'avez aucun travaux à prévoir seulement déposer vos valises.
#  Ne perdez pas de temps et contactez moi pour une visite.
#  Stéphanie ANTON
#  Garage en sus 15.000 Euros
#  Prix FAI 160.400 EUROS
#  - Annonce rédigée et publiée par un Agent Mandataire -.
# ['2 Balcons', 'Surface de 60 m²', 'Année de construction 1975', 'Bâtiment de 4 étages', 'Au 3ème étage', '3 Pièces', '2 Chambres', 'Cuisine aucune', 'Séjour', '1 Box']
# ['NULL', 'NULL']
# -----------------------------------------------------
# Appartement
# Neuilly-sur-Seine
# ['2 pièces', '1 chambre', '41 m²']
# 485 000€
# À partir de 2 008 € / mois
# Hosman vous propose à la vente ce 2 pièces d'une surface de 41,17 m² Carrez, situé Boulevard du Général Koenig à Neuilly-sur-Seine. L'appartement est situé au dernier étage (4ème sur 4) d'un immeuble de 1959.Un ascenseur est présent dans l'immeuble.La résidence est également sécurisée et un gardien réside dans l'immeuble. L'appartement se compose: D'une entrée de 1,63 m2D'un séjour de 17,03 m², exposé Sud Est qui donne sur la cour / la rue / un monument historique.Un balcon de 2,83 m² est rattaché au séjour et est exposé Sud-Est et dispose d'une vue dégagée sur une cour arboré. D'une chambre d'une surface de 11 m², exposée Sud-Est avec une vue dégagée également. D'une cuisine séparée de 8 m² exposée Sud-Est, en état, et dispose de store roulant. D'une salle de bain de 3,53 m² munie d'une baignoire/douche, d'une simple vasque et d'un espace pour installer une machines laver, ainsi qu'un toilette. Elle dispose d'une aération VMC.Il y a des stores électrique roulants dans la chambre et le séjour, manuel dans la cuisine.Une cave de 4 m² complète ce bien.Le bien se situe à 15 minutes à pied de la station Pont de Neuilly (ligne 1). Le bien se situe à proximité de toutes les commodités. La rue de Longchamp (très commerçante) est à 4 minutes à pied.Le Parc de Bagatelle se situe à 7 minutes à pied, ainsi que le Bois de Boulogne.Le système de chauffage est: collectifLes charges de copropriété s'élèvent à 640 euros par trimestre, ce qui comprend le gardiennage, la gestion des poubelles, et l'entretien des parties communesLa taxe foncière est de 600 euros.Le bien est soumis au statut de copropriété.Chez Hosman, nous souhaitons réinventer l'agence immobilière en offrant un service innovant et transparent aux acheteurs et aux vendeurs.Nos frais de commercialisation sont de 4 900 euros fixes à la charge du vendeur. L'équipe Hosman se tient à votre disposition pour répondre à vos questions, organiser une visite ou une estimation de votre bien actuel si cet achat dépend de la vente de votre domicile.
# ['Ascenseur', 'Cave', '1 Balcon', 'Gardien', 'Balcon de 5 m²', 'Orientation Est, Sud', 'Vue', 'Surface de 41 m²', 'Bâtiment de 4 étages', 'Au 4ème étage', '2 Pièces', '1 Chambre', '1 Salle de bain', '1 Toilette', 'Chauffage central', 'Cuisine séparée', 'Entrée', 'Séjour']
# ['216', '50']
# -----------------------------------------------------
# Appartement
# Montreuil
# ['2 pièces', '1 chambre', '46 m²']
# 275 000€
# À partir de 1 142 € / mois
# Proprioo, l'agence nouvelle génération, vous propose à la vente cet appartement de 2 pièces de 46 m² situé dans le quartier du Bel Air-Grands Pêchers.
# Ce bien se situe dans une copropriété bien entretenue de 2017, au premier étage avec ascenseur, sécurisée par un interphone et par un digicode.
# Il se compose d'un séjour avec cuisine US équipée donnant sur un balcon de 8.30 m², d'une chambre, d'une salle de bain et de WC séparés.
# Le bien est en excellent état général et ne nécessite pas de travaux.
# Il est équipé d'un système de chauffage électrique et de doubles vitrages sur l'ensemble des fenêtres.
# Un parking complète ce bien.
# Charges de copropriété: 120 € par mois.
# Ce bien est commercialisé par Proprioo.(gedeon_41509_20838488).
# ['Ascenseur', '1 Balcon', 'Balcon de 8 m²', 'Orientation Est, Nord, Ouest, Sud', 'Refait À Neuf', 'Surface de 46 m²', 'Année de construction 2017', 'Bâtiment de 4 étages', 'Au 1er étage', '2 Pièces', '1 Chambre', '1 Salle de bain', '1 Toilette', 'Toilettes Séparées', 'Chauffage électrique', 'Cuisine équipée', 'Séjour', '1 Parking', 'Interphone', 'Digicode']
# ['NULL', 'NULL']
# -----------------------------------------------------
# Appartement
# Choisy le Roi
# ['5 pièces', '4 chambres', '107,2 m²']
# 483 000€
# À partir de 1 999 € / mois
# CHOISY-LE-ROI SECTEUR DU PORT, DUPLEX de 5 pièces offrant une surface habitable de 108m² il comprend une entrée avec placard, un double séjour cathédrale offrant une triple exposition et une double ouverture sur deux terrasses, une cuisine entièrement équipée moderne et fonctionnelle donnant elle aussi sur une agréable terrasse ! Idéale pour les petits déjeuners du matin ! A l'étage un palier desservant 3 chambres disposant toutes d'un placard, salle de bains, salle d'eau et WC séparé. Le bien dispose d'une place de parking en sous-sol. L'immeuble ne comporte pas de travaux et dispose d'un ascenseur. La proximité des bords de seine se situant de l'autre côté du trottoir est un atout pour les amoureux de balade ou les joggers. RER C CHOISY à 3mn à pieds N'hésitez pas à nous contacter si vous souhaitez organiser une visite ! Dont 5.00 % honoraires TTC à la charge de l'acquéreur. Copropriété de 30 lots (Pas de procédure en cours). Charges annuelles: 2989.00 euros.
# ['Ascenseur', '2 Terrasses', 'Surface de 107,2 m²', 'Année de construction 2007', 'Bâtiment de 4 étages', 'Au 1er étage', '5 Pièces', '4 Chambres', '1 Salle de bain', "1 Salle d'eau", '1 Toilette', 'Toilettes Séparées', 'Rangements', 'Chauffage individuel électrique', 'Cuisine équipée', 'Entrée', 'Séjour', 'Interphone', 'Digicode']
# ['NULL', 'NULL']
# -----------------------------------------------------

# %%
driver.quit()
driver2.quit()

# %%
    #     print(ad_link)

    #     headers_Get = {
    #     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36',
    #     'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    #     'Accept-Language': 'en-US,en;q=0.9',
    #     'DNT': '1',
    #     'Connection': 'keep-alive',
    #     'Upgrade-Insecure-Requests': '1'
    #     }

    #     q = ad_link
    #     s = requests.Session()
    #     url = 'http://' + q 
    #     request2 = s.get(url, headers=headers_Get)
