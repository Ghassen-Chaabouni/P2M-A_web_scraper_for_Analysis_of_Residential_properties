# %%
import pandas as pd
from bs4 import BeautifulSoup as soup
import requests
from selenium import webdriver
import time
from lxml import html
from random import random

# %%
category_data = []
localite_data = []
criterion_data = []
price_data = []
monthly_data = []
description_data = []
plus_data = []
energie_data = []

PROXY = "127.0.0.1:9150"
webdriver.DesiredCapabilities.FIREFOX['proxy']={
    "socksProxy":PROXY,
    "socksVersion":5,
    "proxyType":"MANUAL"
}

max = 20
min = 11

page_num1=42

page_num2=page_num1+1
for num in range(page_num1,page_num2):
    driver = webdriver.Firefox()
    driver.get("https://seloger.com//list.htm?projects=2%2C5&types=1%2C2%2C4%2C3%2C9%2C13%2C14%2C12%2C11%2C10&natures=1%2C2%2C4&places=%5B%7BidPays%3A250%7D%5D&enterprise=0&houseboat=1&qsVersion=1.0&LISTING-LISTpg="+str(num))
    time_random1 = random()
    time1 = min + (time_random1 * (max - min))
    time.sleep(time1)
    url2 = str(driver.current_url)
    if('validate.perfdrive.com' in url2):
        continue
    page = soup(driver.page_source, 'html.parser')
    house_containers = page.find_all("div", class_="block__ShadowedBlock-sc-10w6hsj-0 ListContent__SmartClassifiedExtended-sc-1viyr2k-2 iddbNe classified__ClassifiedContainer-sc-1wmlctl-0 cGCTai Card__CardContainer-sc-7insep-7 kjDrzL")
    print(len(house_containers))
    
    driver2 = webdriver.Firefox()
    for data in house_containers:
        find_link = data.find_all("a", class_="CoveringLink-a3s3kt-0 dXJclF")
        L=str(find_link[0]).split(" ")
        ad_link=L[3][14:-1]
        
       

        if ('seloger.com' not in ad_link):
            continue

        driver2.get("https://" + ad_link)
        time_random2 = random()
        time2 = min + (time_random2 * (max - min))
        time.sleep(time2)
       
        url = str(driver2.current_url)
       
        if('validate.perfdrive.com' in url):
            driver2 = webdriver.Firefox()
            continue
            
        page2 = soup(driver2.page_source, 'html.parser')

        criterion = []
        plus = []
        energie =[]

        try:
            try:
                find_category = page2.find_all("h2", class_="c-h2")[0]
                category = str(find_category)[len('<h2 class="c-h2">'):-5]
            except IndexError:
                find_category = page2.find_all("div", class_="Summary__Text-sc-1wkzvu-6 gcWjRm")[0]
                category=(str(find_category)[len('<div class="Summary__Text-sc-1wkzvu-6 gcWjRm">'):-6])
        except:
            category = "NULL"

        try:
            try:
                find_localite = page2.find_all("p", class_="localite")[0]
                localite = str(find_localite)[len('<p class="localite">'):-4]
            except IndexError:
                find_localite = page2.find_all("div", class_="Summary__Text-sc-1wkzvu-6 gcWjRm")[1]
                localite=(str(find_localite)[len('<div class="Summary__Text-sc-1wkzvu-6 gcWjRm">'):-6])
        except:
            localite = "NULL"

        try:
            try:
                find_criterion = page2.find_all("ul", class_="criterion")[0]
                criterion2 = str(find_criterion).split('<li>')[1:]
                for i in range (len(criterion2)):
                    ch=""
                    for j in range (len(criterion2[i])):
                        if(str(criterion2[i])[j]=="<"):
                            break
                        ch=ch+str(criterion2[i])[j]
                    criterion.append(ch)

            except IndexError:
                find_criterion = page2.find_all("div", class_="Tags__TagContainer-sc-1gccxml-0 kQEoGa")[:3]
                find_criterion = list(map(str, find_criterion))
                for i in range (len(find_criterion)):
                    criterion.append(find_criterion[i][len('<div class="Tags__TagContainer-sc-1gccxml-0 kQEoGa">'):-6])

        except:
            criterion.append("NULL")

        try:
            try:
                find_price = page2.find_all("a", class_="js-smooth-scroll-link price")[0]
                price = str(find_price)[len('<a class="js-smooth-scroll-link price" data-smoothscroll-offset="160" href="#about_price_anchor">'):-4].replace(" ","").replace("\n","")
            except IndexError:
                find_price = page2.find_all("span", class_="global-styles__TextNoWrap-sc-1aeotog-7 iAJdaY")[0]
                price = str(find_price)[len('<span class="global-styles__TextNoWrap-sc-1aeotog-7 iAJdaY">'):-7]
        except:
            price = "NULL"

        try:
            try:
                find_monthly = page2.find_all("a", class_="monthly")[0]
                monthly = str(find_monthly)[len('<a class="monthly" href="https://e-immobilier.credit-agricole.fr/simulca/?ORI=selogercampagne&amp;xtor=AL-2-[partenariat]-[Seloger]-[pdd]-[lien_a_partir_sticky]" rel="nofollow" target="_blank">'):-len('<sup>1</sup></a>')]
            except IndexError:
                find_monthly = page2.find_all("span", class_="global-styles__TextNoWrap-sc-1aeotog-7 iAJdaY")[1]
                monthly = str(find_monthly)[len('<span class="global-styles__TextNoWrap-sc-1aeotog-7 iAJdaY">'):-7]
        except:
            monthly = "NULL"

        try:
            try:
                find_description = page2.find_all("p", class_="sh-text-light")[0]
                description = str(find_description)[len('<p class="sh-text-light" id="js-descriptifBien">'):-4]
            except IndexError:
                find_description = "NULL"
                description ="NULL"
        except:
            description = "NULL"

        try:
            try:
                find_plus = page2.find_all("div", class_="u-left")[0]
                find_plus = page2.find_all("div", class_="u-left")
                for i in range (len(find_plus)):
                    plus2 = str(find_plus[i]).replace('<div class="u-left">', "").replace("</div>", "")
                    plus.append(plus2)

            except IndexError:
                find_plus = page2.find_all("figcaption") + page2.find_all("li", class_="GeneralList__Item-sc-9gtpjm-1 dsevYN")
                for i in range (len(find_plus)):
                    ch=""
                    for j in range (len(str(find_plus[i]))):
                        if(str(find_plus[i])[j]=='>'):
                            k=j
                            while(str(find_plus[i])[k]!="<"):
                                ch=ch + str(find_plus[i])[k]
                                k=k+1
                            break
                    plus.append(ch[1:])
        except:
            plus.append("NULL")

        try:
            try:
                find_energie = page2.find_all("div", class_="info-detail")[0]
                find_energie = page2.find_all("div", class_="info-detail")

                energie.append(str(find_energie[0])[len('<div class="info-detail">'):-6])
                energie.append(str(find_energie[1])[len('<div class="info-detail">'):-6])

            except IndexError:
                find_energie = page2.find_all("span", class_="Preview__PreviewTooltipValue-sc-1pa12ii-4 eGDcBO")
                energie.append(str(find_energie[0])[len('<span class="Preview__PreviewTooltipValue-sc-1pa12ii-4 eGDcBO">'):-7])
                energie.append(str(find_energie[1])[len('<span class="Preview__PreviewTooltipValue-sc-1pa12ii-4 eGDcBO">'):-7])
        except:
            energie.append("NULL")
            energie.append("NULL")


        print(category)
        print(localite)
        print(criterion)
        print(price)
        print(monthly)
        print(description)
        print(plus)
        print(energie)
        print(num)
        print("-----------------------------------------------------")

        category_data.append(str(category))
        localite_data.append(str(localite))
        criterion_data.append(criterion)
        price_data.append(str(price))
        monthly_data.append(str(monthly))
        description_data.append(str(description))
        plus_data.append(plus)
        energie_data.append(energie)

        # driver2.quit()
        
    for i in range (len(criterion_data)):
        if (len(criterion_data[i])==1):
            if("pièce" in criterion_data[i][0]):
                criterion_data[i].insert(1, "NULL")
                criterion_data[i].insert(2, "NULL")
            if("chambre" in criterion_data[i][0]):
                criterion_data[i].insert(0, "NULL")
                criterion_data[i].insert(2, "NULL")
            if("m²" in criterion_data[i][0]):
                criterion_data[i].insert(0, "NULL")
                criterion_data[i].insert(1, "NULL")
        if (len(criterion_data[i])==2):
            if(("pièce" in criterion_data[i][0]) and ("chambre" in criterion_data[i][1])):
                criterion_data[i].insert(2, "NULL")
            if(("pièce" in criterion_data[i][0]) and ("m²" in criterion_data[i][1])):
                criterion_data[i].insert(1, "NULL")
            if(("chambre" in criterion_data[i][0]) and ("m²" in criterion_data[i][1])):
                criterion_data[i].insert(0, "NULL")
        if(len(criterion_data[i])==0):
            criterion_data[i].append("NULL")
            criterion_data[i].append("NULL")
            criterion_data[i].append("NULL")
        
    df = pd.DataFrame()
    df["category"] = category_data
    df["localite"] = localite_data
    df["piece"] = [i[0] for i in criterion_data]
    df["chambres"] = [i[1] for i in criterion_data]
    df["area"] = [i[2] for i in criterion_data]
    df["price"] = price_data
    df["monthly"] = monthly_data
    df["description"] = description_data
    df["Diagnostic de performance énergétique(kWhEP/m².an)"] = [i[0] for i in energie_data]
    df["Indice d'émission de gaz à effet de serre(kgeqCO2/m².an)"] = [i[1] for i in energie_data]
    df["plus"] = plus_data
    df["type"] = "Acheter"
    
    df.to_csv(r"C:\Users\admin\Desktop\9raya\page.csv", index=False)
    csv1 = pd.read_csv(r"C:\Users\admin\Desktop\9raya\page.csv")
    csv2 = pd.read_csv(r"C:\Users\admin\Desktop\9raya\full_data.csv")
    full_data = pd.concat([csv1, csv2])
    full_data.to_csv(r"C:\Users\admin\Desktop\9raya\full_data.csv", index=False)
# Out:
# 25
# Appartement
# Montreuil
# ['2 pièces', '1 chambre', '46m²']
# 275 000 €
# 1 142 €
# NULL
# ['Orientation Sud-Est', '8,3m² Balcon', 'Ascenseur', 'Surface de 46m²', 'Bâtiment de 4 étages', '2 Pièces', '1 Chambre', 'Année de construction 2017', 'Refait à neuf', 'Au 1er étage', '1 Salle de bain', '1 Toilette', 'Toilette séparée', 'Chauffage électrique', 'Cuisine équipée', 'Salle de séjour', '1 Parking', 'Interphone', 'Digicode', 'Orientation Nord-Est']
# ['NULL', 'NULL']
# 42
# -----------------------------------------------------
# Appartement
# Neuilly-sur-Seine
# ['2 pièces', '1 chambre', '41m²']
# 485 000 €
# 2 008 €
# NULL
# ['Orientation Sud-Est', '5m² Balcon', 'Cave', 'Vue', 'Gardien', 'Ascenseur', 'Surface de 41m²', 'Bâtiment de 4 étages', '2 Pièces', '1 Chambre', 'Au 4ème étage', '1 Salle de bain', '1 Toilette', 'Chauffage central', 'Cuisine séparée', 'Une entrée', 'Salle de séjour', 'Orientation Est']
# ['216', '50']
# 42
# -----------------------------------------------------
# NULL
# NULL
# []
# NULL
# NULL
# NULL
# []
# ['NULL', 'NULL']
# 42
# -----------------------------------------------------
# Maison / Villa
# Bastia
# ['7 pièces', '4 chambres', '230m²']
# 985 000 €
# 4 068 €
# NULL
# ['Orientation Sud-Est', '28m² Cave', 'Cheminée', 'Surface de 230m²', 'Bâtiment de 2 étages', '7 Pièces', '4 Chambres', 'Adapté PMR', '3 Salles de bain', '3 Toilettes', 'Rangements', 'Chauffage individuel', 'Cuisine séparée équipée', 'Salle à manger', 'Terrain de 3200m²', '5 Parkings', '3 Boxs', 'Travaux', 'Orientation Est', 'Calme', 'Situation : mer']
# ['NULL', 'NULL']
# 42
# -----------------------------------------------------
# Maison / Villa
# Campitello
# ['8 pièces', '5 chambres', '280m²']
# 420 000 €
# 1 740 €
# NULL
# ['1 Terrasse', 'Vue', 'Cheminée', 'Surface de 280m²', 'Bâtiment de 3 étages', '8 Pièces', '5 Chambres', 'Année de construction 1930', '1 Salle de bain', "2 Salles d'eau", '4 Toilettes', 'Rangements', 'Chauffage individuel électrique sol', 'Cuisine américaine équipée', 'Une entrée', 'Salle à manger', 'Terrain de 500m²']
# ['NULL', 'NULL']
# 42
# -----------------------------------------------------
# Appartement
# Bormes-les-Mimosas
# ['3 pièces', '2 chambres', '59,7m²']
# 308 000 €
# 1 278 €
# NULL
# ['2 Terrasses', 'Piscine', 'Ascenseur', 'Surface de 59,7m²', 'Bâtiment de 2 étages', '3 Pièces', '2 Chambres', 'Année de construction 2019', 'Au 1er étage', 'Adapté PMR', "1 Salle d'eau", '1 Toilette', 'Chauffage individuel électrique', 'Cuisine aucune', 'Salle de séjour', 'Interphone']
# ['NULL', 'NULL']
# 42
# -----------------------------------------------------
# Maison / Villa
# Coulommiers
# ['6 pièces', '5 chambres', '180m²']
# 131 875 €
# 552 €
# NULL
# ['Cave', 'Surface de 180m²', '6 Pièces', '5 Chambres', 'Année de construction 1962', 'Chauffage individuel', 'Cuisine séparée équipée', 'Salle de séjour', 'Terrain de 7085m²', '1 Parking', 'Calme']
# ['330', 'NULL', 'NULL']
# 42
# -----------------------------------------------------
# Maison / Villa
# Jarville-la-Malgrange
# ['8 pièces', '4 chambres', '238m²']
# 294 900 €
# 1 224 €
# NULL
# ['Orientation Sud-Ouest', '1 Terrasse', 'Surface de 238m²', '8 Pièces', '4 Chambres', 'Année de construction 1970', "1 Salle d'eau", 'Chauffage individuel gaz', 'Cuisine aucune', 'Terrain de 500m²', 'Orientation Ouest']
# ['234', '52']
# 42
# -----------------------------------------------------
# Appartement
# Nice
# ['3 pièces', '2 chambres', '55,49m²']
# 178 500 €
# 745 €
# NULL
# ['Cave', '1 Balcon', '1 Terrasse', 'Vue', 'Ascenseur', 'Surface de 55,49m²', 'Bâtiment de 13 étages', '3 Pièces', '2 Chambres', 'Année de construction 1947', 'Au 5ème étage', '1 Salle de bain', '1 Toilette', 'Rangements', 'Chauffage individuel électrique', 'Cuisine séparée', 'Salle de séjour : 14,35m²', 'Interphone', 'Orientation Est']
# ['NULL', 'NULL']
# 42
# -----------------------------------------------------
# Appartement
# Carrières-sous-Poissy
# ['3 pièces', '2 chambres', '56,2m²']
# 229 500 €
# 955 €
# NULL
# ['Orientation Sud', '1 Terrasse', 'Ascenseur', 'Surface de 56,2m²', 'Bâtiment de 4 étages', '3 Pièces', '2 Chambres', 'Année de construction 2007', 'Rez-de-chaussée', "1 Salle d'eau", '1 Toilette', 'Rangements', 'Chauffage individuel électrique radiateur', 'Cuisine américaine', 'Une entrée', 'Salle de séjour', '2 Parkings', 'Interphone', 'Digicode']
# ['245', '13']
# 42
# -----------------------------------------------------
# Maison / Villa
# Saint-Jean-de-Gonville
# ['9 pièces', '4 chambres', '226m²']
# 829 000 €
# 3 425 €
# NULL
# ['1 Terrasse', 'Cheminée', 'Surface de 226m²', 'Bâtiment de 2 étages', '9 Pièces', '4 Chambres', 'Adapté PMR', '1 Salle de bain', "1 Salle d'eau", '2 Toilettes', 'Rangements', 'Chauffage sol', 'Cuisine séparée équipée', 'Une entrée', 'Salle à manger', 'Salle de séjour', 'Terrain de 320m²', 'Alarme', 'Orientation Est']
# ['143', '5']
# 42
# -----------------------------------------------------
# Appartement
# Beaune
# ['2 pièces', '1 chambre', '60m²']
# 199 000 €
# 829 €
# NULL
# ['Surface de 60m²', 'Bâtiment de 3 étages', '2 Pièces', '1 Chambre', 'Année de construction 1900', 'Duplex', 'Au 1er étage', '1 Salle de bain', '1 Toilette', 'Toilette séparée', 'Parquet', 'Chauffage individuel électrique radiateur', 'Cuisine équipée', 'Salle de séjour : 30m²', 'Orientation Ouest', 'Calme']
# ['310', '10']
# 42
# -----------------------------------------------------
# Maison / Villa
# Neffiès
# ['4 pièces', '2 chambres', '94,21m²']
# 128 500 €
# 539 €
# NULL
# ['Vue', 'Cheminée', 'Surface de 94,21m²', '4 Pièces', '2 Chambres', '2 Salles de bain', '1 Toilette', 'Chauffage individuel', 'Salle à manger', 'Salle de séjour : 25,69m²', 'Terrain de 1328m²', '1 Box']
# ['184', '4']
# 42
# -----------------------------------------------------
# Appartement
# Mandelieu-la-Napoule
# ['1 pièce', '29,09m²', '1 pièce']
# 119 000 €
# 499 €
# NULL
# ['1 Terrasse', 'Ascenseur', 'Surface de 29,09m²', '1 Pièce', 'Au 1er étage', '1 Salle de bain', "1 Salle d'eau", '1 Toilette', 'Toilette séparée', 'Rangements', 'Chauffage individuel', 'Salle de séjour : 19,21m²', '1 Parking', 'Calme']
# ['126', '3']
# 42
# -----------------------------------------------------
# Maison / Villa
# La Verdière
# ['5 pièces', '3 chambres', '142m²']
# 103 800 €
# 437 €
# NULL
# ['Cave', '1 Terrasse', 'Piscine', 'Cheminée', 'Surface de 142m²', '5 Pièces', '3 Chambres', 'Année de construction 2000', "1 Salle d'eau", '1 Toilette', 'Toilette séparée', 'Chauffage électrique', 'Cuisine américaine équipée', 'Salle à manger', 'Terrain de 2749m²', '1 Parking', 'Calme']
# ['145', '10']
# 42
# -----------------------------------------------------
# Maison / Villa
# Verfeil
# ['13 pièces', '6 chambres', '530m²']
# 919 910 €
# 3 800 €
# NULL
# ['Cave', 'Piscine', 'Cheminée', 'Surface de 530m²', '13 Pièces', '6 Chambres', '1 Salle de bain', "2 Salles d'eau", '3 Toilettes', 'Chauffage fuel', 'Une entrée', 'Salle à manger : 61m²', 'Salle de séjour : 24m²', 'Terrain de 1150m²', '1 Box']
# ['95', '28']
# 42
# -----------------------------------------------------
# Appartement
# Rambouillet
# ['5 pièces', '3 chambres', '130m²']
# 420 000 €
# 1 740 €
# NULL
# ['Cave', 'Vue', 'Ascenseur', 'Surface de 130m²', 'Bâtiment de 4 étages', '5 Pièces', '3 Chambres', 'Année de construction 1967', 'Au 1er étage', '1 Salle de bain', "1 Salle d'eau", '1 Toilette', 'Toilette séparée', 'Rangements', 'Télévision', 'Chauffage central', 'Cuisine séparée', 'Une entrée', 'Salle de séjour : 52m²', '1 Parking', 'Travaux', 'Interphone', 'Digicode', 'Orientation Est', 'Calme', 'Situation : ville', "Inscrit à l'Ismh"]
# ['313', '73']
# 42
# -----------------------------------------------------
# Appartement
# Perpignan
# ['5 pièces', '3 chambres', '107m²']
# 56 760 €
# 243 €
# NULL
# ['Surface de 107m²', 'Bâtiment de 12 étages', '5 Pièces', '3 Chambres', 'Au 2ème étage', "1 Salle d'eau", '1 Toilette', 'Toilette séparée', 'Chauffage gaz collectif', 'Cuisine américaine', 'Salle de séjour']
# ['100', '17']
# 42
# -----------------------------------------------------
# Appartement
# Vernouillet
# ['1 pièce', '29m²', '1 pièce']
# 126 000 €
# 528 €
# NULL
# ['Surface de 29m²', 'Bâtiment de 2 étages', '1 Pièce', 'Année de construction 1987', 'Au 1er étage', "1 Salle d'eau", '1 Toilette', 'Toilette séparée', 'Chauffage individuel électrique', 'Cuisine aucune', 'Salle de séjour', '1 Parking', 'Interphone', 'Orientation Nord-Ouest', 'Calme']
# ['406', '23']
# 42
# -----------------------------------------------------
# Appartement
# Bayonne
# ['4 pièces', '3 chambres', '91,27m²']
# 430 000 €
# 1 781 €
# NULL
# ['Orientation Sud-Ouest', '1 Terrasse', 'Ascenseur', 'Surface de 91,27m²', 'Bâtiment de 2 étages', '4 Pièces', '3 Chambres', 'Au 2ème étage', '1 Salle de bain', "1 Salle d'eau", '2 Toilettes', 'Rangements', 'Chauffage individuel gaz', '2 Parkings', 'Interphone', 'Orientation Ouest']
# ['50', '5']
# 42
# -----------------------------------------------------
# Appartement
# Bayonne
# ['4 pièces', '3 chambres', '88,85m²']
# 385 000 €
# 1 595 €
# NULL
# ['1 Terrasse', 'Ascenseur', 'Surface de 88,85m²', 'Bâtiment de 2 étages', '4 Pièces', '3 Chambres', 'Au 3ème étage', '1 Salle de bain', "1 Salle d'eau", '2 Toilettes', 'Rangements', 'Chauffage individuel gaz', '2 Parkings', 'Interphone', 'Orientation Ouest', 'Calme']
# ['50', '5']
# 42
# -----------------------------------------------------
# Appartement
# Villefranche-sur-Saône
# ['4 pièces', '3 chambres', '99m²']
# 101 470 €
# 427 €
# NULL
# ['Cave', '1 Balcon', 'Vue', 'Piscine', 'Gardien', 'Surface de 99m²', 'Bâtiment de 6 étages', '4 Pièces', '3 Chambres', 'Année de construction 1990', 'Au 1er étage', '1 Salle de bain', "1 Salle d'eau", 'Chauffage électrique', 'Cuisine séparée', 'Salle de séjour', '1 Parking', 'Calme']
# ['302', 'NULL', 'NULL']
# 42
# -----------------------------------------------------
# Maison / Villa
# Pigny
# ['5 pièces', '4 chambres', '124m²']
# 183 900 €
# 767 €
# NULL
# ['Orientation Sud', '1 Terrasse', 'Surface de 124m²', '5 Pièces', '4 Chambres', 'Année de construction 2004', '2 Salles de bain', '1 Toilette', 'Toilette séparée', 'Parquet', 'Chauffage individuel électrique radiateur', 'Salle à manger', 'Salle de séjour : 35m²', 'Terrain de 900m²']
# ['182', '9']
# 42
# -----------------------------------------------------

# %%
driver.quit()
driver2.quit()

# %%
full_data = full_data.dropna(thresh=9)
full_data.to_csv(r"C:\Users\admin\Desktop\9raya\full_data2.csv", index=False)

# %%
    #     print(ad_link)

    #     headers_Get = {
    #     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36',
    #     'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    #     'Accept-Language': 'en-US,en;q=0.9',
    #     'DNT': '1',
    #     'Connection': 'keep-alive',
    #     'Upgrade-Insecure-Requests': '1'
    #     }

    #     q = ad_link
    #     s = requests.Session()
    #     url = 'http://' + q 
    #     request2 = s.get(url, headers=headers_Get)
